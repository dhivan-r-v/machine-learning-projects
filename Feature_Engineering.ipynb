# %% [markdown]
# ### Feature Engineering
#
# Whatever you do wih features, we call it as Feature Engineering.
#
# * Feature Elimination    - dropping the features.
# * Feature Addition       - adding some features.
# * Feature Transformation - transforming the given feature values into an another scale - Log Tranformation, Sqrt Transformation..
# * Feature Selection      - deciding which features are important out of many features and choosing that features for model building.

# %% [markdown]
# #### Feature Selection Techniques
#
# * sklearn - SelectFromModel
# * sklearn - RFE(ie,Recursive Feature Elimination)

# %% [markdown]
# ## 1.Import Necessary Libraries

# %%
import pandas as pd

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE,SelectFromModel
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 2.Load Datasets

# %%
breast_cancer=load_breast_cancer()
x=breast_cancer.data
y=breast_cancer.target

# %% [markdown]
# ## 3.Data Undertanding

# %%
x.shape,y.shape
# Out:
# ((569, 30), (569,))

# %% [markdown]
# ## 4.Model Building

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=25,shuffle=True,stratify=y)

# %%
x_train.shape,y_train.shape
# Out:
# ((455, 30), (455,))

# %%
x_test.shape,y_test.shape
# Out:
# ((114, 30), (114,))

# %% [markdown]
# ### 5.Model Training || 6.Model Testing || 7.Model Evaluation

# %%
rf_model=RandomForestClassifier(max_depth=7)
rf_model.fit(x_train,y_train)

y_pred_test=rf_model.predict(x_test)

print("Test Accuracy:",round(accuracy_score(y_test,y_pred_test),4))
print("Test Precision:",round(precision_score(y_test,y_pred_test),4))
print("Test recall:",round(recall_score(y_test,y_pred_test),4))
print("Test confusion matrix:\n",confusion_matrix(y_test,y_pred_test))
# Out:
# Test Accuracy: 0.9649
# Test Precision: 0.9722
# Test recall: 0.9722
# Test confusion matrix:
#  [[40  2]
#  [ 2 70]]

# %%
rf_model.feature_importances_
# Out:
# array([0.03151999, 0.01132011, 0.04814683, 0.04467746, 0.00646057,
#        0.01517554, 0.07138121, 0.10448323, 0.0029365 , 0.00444324,
#        0.01745591, 0.00562553, 0.01554726, 0.04722388, 0.00240183,
#        0.00433387, 0.00734671, 0.0042608 , 0.00405654, 0.0041244 ,
#        0.08339142, 0.01872715, 0.16676259, 0.094729  , 0.01292921,
#        0.00923145, 0.05806819, 0.08549717, 0.00840862, 0.00933377])

# %%
select_from_model=SelectFromModel(estimator=RandomForestClassifier(),max_features=None)
select_from_model.fit(x_train,y_train)
# Out:
# SelectFromModel(estimator=RandomForestClassifier())

# %%
select_from_model.get_support()
# Out:
# array([False, False, False,  True, False, False,  True,  True, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False,  True, False,  True,  True, False, False,  True,
#         True, False, False])

# %%
breast_cancer.feature_names[select_from_model.get_support()]
# Out:
# array(['mean area', 'mean concavity', 'mean concave points', 'area error',
#        'worst radius', 'worst perimeter', 'worst area', 'worst concavity',
#        'worst concave points'], dtype='<U23')

# %%
x_train_select_from_model=select_from_model.transform(x_train)
x_test_select_from_model=select_from_model.transform(x_test)

# %%
x_train_select_from_model.shape,x_test_select_from_model.shape
# Out:
# ((455, 9), (114, 9))

# %%
def runRandomForestClassifier(x_train,x_test,y_train,y_test):
    rf_model=RandomForestClassifier(max_depth=7,random_state=123)
    rf_model.fit(x_train,y_train)
    
    y_pred_test=rf_model.predict(x_test)
    
    print("Test Accuracy:",round(accuracy_score(y_test,y_pred_test),4))
    print("Test Precision:",round(precision_score(y_test,y_pred_test),4))
    print("Test recall:",round(recall_score(y_test,y_pred_test),4))
    print("Test confusion matrix:\n",confusion_matrix(y_test,y_pred_test))

# %%
# %%time
runRandomForestClassifier(x_train,x_test,y_train,y_test)
# Out:
# Test Accuracy: 0.9737
# Test Precision: 0.9859
# Test recall: 0.9722
# Test confusion matrix:
#  [[41  1]
#  [ 2 70]]
# CPU times: total: 625 ms
# Wall time: 787 ms

# %%
# %%time
runRandomForestClassifier(x_train_select_from_model,x_test_select_from_model,y_train,y_test)
# Out:
# Test Accuracy: 0.9649
# Test Precision: 0.9857
# Test recall: 0.9583
# Test confusion matrix:
#  [[41  1]
#  [ 3 69]]
# CPU times: total: 391 ms
# Wall time: 371 ms

# %% [markdown]
# ## 2nd Techniques RFE(Recursive Feature Elimination)

# %%
rfe_model=RFE(estimator = RandomForestClassifier(), n_features_to_select=12)
rfe_model.fit(x_train,y_train)
# Out:
# RFE(estimator=RandomForestClassifier(), n_features_to_select=12)

# %%
rfe_model.get_support()
# Out:
# array([ True, False,  True,  True, False, False,  True,  True, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False,  True,  True,  True,  True, False, False,  True,
#         True, False, False])

# %%
breast_cancer.feature_names[rfe_model.get_support()]
# Out:
# array(['mean radius', 'mean perimeter', 'mean area', 'mean concavity',
#        'mean concave points', 'area error', 'worst radius',
#        'worst texture', 'worst perimeter', 'worst area',
#        'worst concavity', 'worst concave points'], dtype='<U23')

# %%
x_train_rfe_model=rfe_model.transform(x_train)
x_test_rfe_model=rfe_model.transform(x_test)

# %%
x_train_rfe_model.shape,x_test_rfe_model.shape
# Out:
# ((455, 12), (114, 12))

# %%
# %%time
runRandomForestClassifier(x_train,x_test,y_train,y_test)
# Out:
# Test Accuracy: 0.9737
# Test Precision: 0.9859
# Test recall: 0.9722
# Test confusion matrix:
#  [[41  1]
#  [ 2 70]]
# CPU times: total: 625 ms
# Wall time: 1.1 s

# %%
# %%time
runRandomForestClassifier(x_train_rfe_model,x_test_rfe_model,y_train,y_test)
# Out:
# Test Accuracy: 0.9649
# Test Precision: 0.9857
# Test recall: 0.9583
# Test confusion matrix:
#  [[41  1]
#  [ 3 69]]
# CPU times: total: 547 ms
# Wall time: 567 ms

# %% [markdown]
# ## 3. Take the important features from GradientBoosting and train it with in RandomForest Algorithm

# %%
rfe_model=RFE(estimator = GradientBoostingClassifier(), n_features_to_select=12)
rfe_model.fit(x_train,y_train)
# Out:
# RFE(estimator=GradientBoostingClassifier(), n_features_to_select=12)

# %%
rfe_model.get_support()
# Out:
# array([False,  True, False, False, False, False, False,  True, False,
#         True,  True, False, False,  True, False, False, False, False,
#        False, False,  True,  True,  True,  True, False, False,  True,
#         True,  True, False])

# %%
breast_cancer.feature_names[rfe_model.get_support()]
# Out:
# array(['mean texture', 'mean concave points', 'mean fractal dimension',
#        'radius error', 'area error', 'worst radius', 'worst texture',
#        'worst perimeter', 'worst area', 'worst concavity',
#        'worst concave points', 'worst symmetry'], dtype='<U23')

# %%
x_train_rfe_model=rfe_model.transform(x_train)
x_test_rfe_model=rfe_model.transform(x_test)

# %%
x_train_rfe_model.shape,x_test_rfe_model.shape
# Out:
# ((455, 12), (114, 12))

# %%
# %%time
runRandomForestClassifier(x_train,x_test,y_train,y_test)
# Out:
# Test Accuracy: 0.9737
# Test Precision: 0.9859
# Test recall: 0.9722
# Test confusion matrix:
#  [[41  1]
#  [ 2 70]]
# CPU times: total: 500 ms
# Wall time: 595 ms

# %%
# %%time
runRandomForestClassifier(x_train_rfe_model,x_test_rfe_model,y_train,y_test)
# Out:
# Test Accuracy: 0.9561
# Test Precision: 0.9718
# Test recall: 0.9583
# Test confusion matrix:
#  [[40  2]
#  [ 3 69]]
# CPU times: total: 531 ms
# Wall time: 548 ms

# %% [markdown]
# ### 4.How to choose the optimal no of features to train my model?

# %%
def runRandomForestClassifier(x_train,x_test,y_train,y_test):
    rf_model=RandomForestClassifier(max_depth=7,random_state=123)
    rf_model.fit(x_train,y_train)
    
    y_pred_test=rf_model.predict(x_test)
    
    print("Test Accuracy:",round(accuracy_score(y_test,y_pred_test),4))
    print("Test Precision:",round(precision_score(y_test,y_pred_test),4))
    print("Test recall:",round(recall_score(y_test,y_pred_test),4))
    print("Test confusion matrix:\n",confusion_matrix(y_test,y_pred_test))

# %%
for i in range(1,31):
    rfe_model=RFE(estimator = GradientBoostingClassifier(), n_features_to_select=i)
    rfe_model.fit(x_train,y_train)
    x_train_rfe_model=rfe_model.transform(x_train)
    x_test_rfe_model=rfe_model.transform(x_test)
    print("Selected Feature : ",i)
    runRandomForestClassifier(x_train_rfe_model,x_test_rfe_model,y_train,y_test)
    print("---------------------------------------------------------")
# Out:
# Selected Feature :  1
# Test Accuracy: 0.8947
# Test Precision: 0.9286
# Test recall: 0.9028
# Test confusion matrix:
#  [[37  5]
#  [ 7 65]]
# ---------------------------------------------------------
# Selected Feature :  2
# Test Accuracy: 0.9123
# Test Precision: 0.9429
# Test recall: 0.9167
# Test confusion matrix:
#  [[38  4]
#  [ 6 66]]
# ---------------------------------------------------------
# Selected Feature :  3
# Test Accuracy: 0.9474
# Test Precision: 0.9583
# Test recall: 0.9583
# Test confusion matrix:
#  [[39  3]
#  [ 3 69]]
# ---------------------------------------------------------
# Selected Feature :  4
# Test Accuracy: 0.9649
# Test Precision: 0.9722
# Test recall: 0.9722
# Test confusion matrix:
#  [[40  2]
#  [ 2 70]]
# ---------------------------------------------------------
# Selected Feature :  5
# Test Accuracy: 0.9737
# Test Precision: 0.9859
# Test recall: 0.9722
# Test confusion matrix:
#  [[41  1]
#  [ 2 70]]
# ---------------------------------------------------------
# Selected Feature :  6
# Test Accuracy: 0.9737
# Test Precision: 0.9859
# Test recall: 0.9722
# Test confusion matrix:
#  [[41  1]
#  [ 2 70]]
# ---------------------------------------------------------
# Selected Feature :  7
# Test Accuracy: 0.9561
# Test Precision: 0.9718
# Test recall: 0.9583
# Test confusion matrix:
#  [[40  2]
#  [ 3 69]]
# ---------------------------------------------------------
# Selected Feature :  8
# Test Accuracy: 0.9649
# Test Precision: 0.9722
# Test recall: 0.9722
# Test confusion matrix:
#  [[40  2]
#  [ 2 70]]
# ---------------------------------------------------------
# Selected Feature :  9
# Test Accuracy: 0.9737
# Test Precision: 0.9859
# Test recall: 0.9722
# Test confusion matrix:
#  [[41  1]
#  [ 2 70]]
# ---------------------------------------------------------
# Selected Feature :  10
# Test Accuracy: 0.9561
# Test Precision: 0.9718
# Test recall: 0.9583
# Test confusion matrix:
#  [[40  2]
#  [ 3 69]]
# ---------------------------------------------------------
# Selected Feature :  11
# Test Accuracy: 0.9649
# Test Precision: 0.9722
# Test recall: 0.9722
# Test confusion matrix:
#  [[40  2]
#  [ 2 70]]
# ---------------------------------------------------------
# Selected Feature :  12
# Test Accuracy: 0.9649
# Test Precision: 0.9857
# Test recall: 0.9583
# Test confusion matrix:
#  [[41  1]
#  [ 3 69]]
# ---------------------------------------------------------
# Selected Feature :  13
# Test Accuracy: 0.9561
# Test Precision: 0.9718
# Test recall: 0.9583
# Test confusion matrix:
#  [[40  2]
#  [ 3 69]]
# ---------------------------------------------------------
# Selected Feature :  14
# Test Accuracy: 0.9561
# Test Precision: 0.9718
# Test recall: 0.9583
# Test confusion matrix:
#  [[40  2]
#  [ 3 69]]
# ---------------------------------------------------------
# Selected Feature :  15
# Test Accuracy: 0.9649
# Test Precision: 0.9857
# Test recall: 0.9583
# Test confusion matrix:
#  [[41  1]
#  [ 3 69]]
# ---------------------------------------------------------
# Selected Feature :  16
# Test Accuracy: 0.9649
# Test Precision: 0.9722
# Test recall: 0.9722
# Test confusion matrix:
#  [[40  2]
#  [ 2 70]]
# ---------------------------------------------------------
# Selected Feature :  17
# Test Accuracy: 0.9561
# Test Precision: 0.9718
# Test recall: 0.9583
# Test confusion matrix:
#  [[40  2]
#  [ 3 69]]
# ---------------------------------------------------------
# Selected Feature :  18
# Test Accuracy: 0.9561
# Test Precision: 0.9718
# Test recall: 0.9583
# Test confusion matrix:
#  [[40  2]
#  [ 3 69]]
# ---------------------------------------------------------
# Selected Feature :  19
# Test Accuracy: 0.9561
# Test Precision: 0.9718
# Test recall: 0.9583
# Test confusion matrix:
#  [[40  2]
#  [ 3 69]]
# ---------------------------------------------------------
# Selected Feature :  20
# Test Accuracy: 0.9474
# Test Precision: 0.9583
# Test recall: 0.9583
# Test confusion matrix:
#  [[39  3]
#  [ 3 69]]
# ---------------------------------------------------------
# Selected Feature :  21
# Test Accuracy: 0.9649
# Test Precision: 0.9857
# Test recall: 0.9583
# Test confusion matrix:
#  [[41  1]
#  [ 3 69]]
# ---------------------------------------------------------
# Selected Feature :  22
# Test Accuracy: 0.9561
# Test Precision: 0.9718
# Test recall: 0.9583
# Test confusion matrix:
#  [[40  2]
#  [ 3 69]]
# ---------------------------------------------------------
# Selected Feature :  23
# Test Accuracy: 0.9649
# Test Precision: 0.9857
# Test recall: 0.9583
# Test confusion matrix:
#  [[41  1]
#  [ 3 69]]
# ---------------------------------------------------------
# Selected Feature :  24
# Test Accuracy: 0.9561
# Test Precision: 0.9718
# Test recall: 0.9583
# Test confusion matrix:
#  [[40  2]
#  [ 3 69]]
# ---------------------------------------------------------
# Selected Feature :  25
# Test Accuracy: 0.9649
# Test Precision: 0.9857
# Test recall: 0.9583
# Test confusion matrix:
#  [[41  1]
#  [ 3 69]]
# ---------------------------------------------------------
# Selected Feature :  26
# Test Accuracy: 0.9561
# Test Precision: 0.9589
# Test recall: 0.9722
# Test confusion matrix:
#  [[39  3]
#  [ 2 70]]
# ---------------------------------------------------------
# Selected Feature :  27
# Test Accuracy: 0.9649
# Test Precision: 0.9722
# Test recall: 0.9722
# Test confusion matrix:
#  [[40  2]
#  [ 2 70]]
# ---------------------------------------------------------
# Selected Feature :  28
# Test Accuracy: 0.9649
# Test Precision: 0.9722
# Test recall: 0.9722
# Test confusion matrix:
#  [[40  2]
#  [ 2 70]]
# ---------------------------------------------------------
# Selected Feature :  29
# Test Accuracy: 0.9561
# Test Precision: 0.9718
# Test recall: 0.9583
# Test confusion matrix:
#  [[40  2]
#  [ 3 69]]
# ---------------------------------------------------------
# Selected Feature :  30
# Test Accuracy: 0.9737
# Test Precision: 0.9859
# Test recall: 0.9722
# Test confusion matrix:
#  [[41  1]
#  [ 2 70]]
# ---------------------------------------------------------

# %% [markdown]
# ### THE END
